# %%
# !python track.py --source ./영상샘플/compound_skip_new_sample.mp4 --save-vid --class 2 --yolo-weights yolov8n.pt --imgsz 1920 --name 'VERI-Wild' --video-mask ./masking/compound_mask.jpg --reid-model onnx_models/VeRi_Wild/baseline_R50.onnx --reid-threshold 'VERI-Wild'
# Out:
# track: yolo_weights=[PosixPath('yolov8n.pt')], reid_weights=/content/drive/.shortcut-targets-by-id/1OghHBwkh9XieWVQthdlRvY2JkM-YDxXO/gosari/yolov8_tracking_hs/yolov8_tracking/weights/osnet_x0_25_msmt17.pt, tracking_method=bytetrack, tracking_config=trackers/bytetrack/configs/bytetrack.yaml, source=/content/drive/MyDrive/공유폴더/CCTV_vid/compound_skip_new_sample.mp4, imgsz=[1920, 1920], conf_thres=0.5, iou_thres=0.5, max_det=1000, device=, show_vid=False, save_txt=False, save_conf=False, save_crop=False, save_trajectories=False, save_vid=True, nosave=False, classes=[2], agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/track, name=VERI-Wild, exist_ok=False, line_thickness=2, hide_labels=False, hide_conf=False, hide_class=False, half=False, dnn=False, vid_stride=1, retina_masks=False, video_mask=/content/drive/MyDrive/공유폴더/yolov8_tracking_masking/yolov8_tracking/masking/compound_mask.jpg, reid_model=/content/drive/MyDrive/공유폴더/reid_onnx_deplo
# ...
